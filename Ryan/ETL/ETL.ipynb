# %%
import pandas as pd

# %%
# clean_data
glacier=pd.read_csv('Resources/glacier_mass.csv')
co2_level=pd.read_csv('Resources/global_co2_level.csv')
emissions=pd.read_csv('Resources/global_emissions.csv')
temp=pd.read_csv('Resources/global_temp.csv')
sea_level=pd.read_csv('Resources/sea_level_change.csv')

# %%
print(len(emissions['Total']))
emissions.head()
# Out:
# 260
#    Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 0  1751      3         0            0           3       0            0
# 1  1752      3         0            0           3       0            0
# 2  1753      3         0            0           3       0            0
# 3  1754      3         0            0           3       0            0
# 4  1755      3         0            0           3       0            0
#
#    Per Capita
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
print(temp.Year.min())
temp.head()
# Out:
# 1880
#     Source  Year    Mean
# 0     GCAG  2016  0.9363
# 1  GISTEMP  2016  0.9900
# 2     GCAG  2015  0.8998
# 3  GISTEMP  2015  0.8700
# 4     GCAG  2014  0.7408

# %%
# set all date ranges the same
glacier=glacier.loc[glacier['Year']>= 1959]
glacier=glacier.loc[glacier['Year']<= 2010]
glacier.head()
# Out:
#     Year  Mean cumulative mass balance  Number of observations
# 14  1959                        -8.325                    11.0
# 15  1960                        -8.688                    14.0
# 16  1961                        -8.935                    15.0
# 17  1962                        -9.109                    20.0
# 18  1963                        -9.567                    22.0

# %%
sea_level=sea_level.loc[sea_level['Time']>= '1959-03-15']
sea_level=sea_level.loc[sea_level['Time']<= '2010-03-15']
sea=sea_level.GMSL.to_list()

# %%
co2_level=co2_level.loc[co2_level['Year']>= '1959-11-01']
co2_level=co2_level.loc[co2_level['Year']<= '2010-11-01']
co2=co2_level['Annual Increase'].to_list()

# %%
emissions.head()
# Out:
#    Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 0  1751      3         0            0           3       0            0
# 1  1752      3         0            0           3       0            0
# 2  1753      3         0            0           3       0            0
# 3  1754      3         0            0           3       0            0
# 4  1755      3         0            0           3       0            0
#
#    Per Capita
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
emissions=emissions.loc[emissions['Year']>= 1959]
emissions=emissions.loc[emissions['Year']<= 2010]
emissions.describe()
# Out:
#               Year        Total     Gas Fuel  Liquid Fuel   Solid Fuel  \
# count    52.000000    52.000000    52.000000    52.000000    52.000000
# mean   1984.500000  5506.038462   877.750000  2251.423077  2154.846154
# std      15.154757  1775.720036   428.173727   656.204127   654.166537
# min    1959.000000  2454.000000   206.000000   789.000000  1349.000000
# 25%    1971.750000  4334.000000   552.500000  2029.500000  1571.750000
# 50%    1984.500000  5404.000000   819.500000  2395.000000  2165.500000
# 75%    1997.250000  6618.250000  1217.500000  2709.250000  2445.750000
# max    2010.000000  9167.000000  1702.000000  3122.000000  3842.000000
#
#            Cement  Gas Flaring  Per Capita
# count   52.000000    52.000000   52.000000
# mean   161.788462    60.326923    1.112500
# std    103.400864    22.908789    0.118353
# min     40.000000    33.000000    0.830000
# 25%     87.750000    43.500000    1.100000
# 50%    129.500000    52.000000    1.130000
# 75%    209.000000    71.500000    1.172500
# max    450.000000   110.000000    1.330000

# %%
temp=temp.loc[temp['Year']>= 1959]
temp=temp.loc[temp['Year']<= 2010]
temp.head()
# Out:
#      Source  Year    Mean
# 12     GCAG  2010  0.7014
# 13  GISTEMP  2010  0.7100
# 14     GCAG  2009  0.6367
# 15  GISTEMP  2009  0.6400
# 16     GCAG  2008  0.5419

# %%
gcag_temp=temp.loc[temp['Source']=='GCAG']
gcag_temp=gcag_temp.sort_values("Year")
gcag_temp_val=gcag_temp.Mean.to_list()
gcag_temp_val
# Out:
# [0.0596,
#  0.0204,
#  0.0775,
#  0.0888,
#  0.1068,
#  -0.1495,
#  -0.078,
#  -0.0227,
#  -0.0131,
#  -0.0296,
#  0.0929,
#  0.0372,
#  -0.0783,
#  0.0264,
#  0.1641,
#  -0.0719,
#  0.0034,
#  -0.0792,
#  0.1978,
#  0.1123,
#  0.2273,
#  0.2637,
#  0.2999,
#  0.1815,
#  0.3411,
#  0.149,
#  0.1342,
#  0.2296,
#  0.3696,
#  0.3757,
#  0.297,
#  0.4328,
#  0.4055,
#  0.2571,
#  0.2853,
#  0.3409,
#  0.4577,
#  0.3228,
#  0.5187,
#  0.6344,
#  0.4438,
#  0.4262,
#  0.5473,
#  0.6023,
#  0.6134,
#  0.5783,
#  0.6585,
#  0.6125,
#  0.61,
#  0.5419,
#  0.6367,
#  0.7014]

# %%
gis_temp=temp.loc[temp['Source']=='GISTEMP']
gis_temp=gis_temp.sort_values("Year")
gis_temp_val=gis_temp.Mean.to_list()
gis_temp_val
# Out:
# [0.03,
#  -0.02,
#  0.05,
#  0.03,
#  0.06,
#  -0.2,
#  -0.1,
#  -0.05,
#  -0.02,
#  -0.07,
#  0.07,
#  0.02,
#  -0.09,
#  0.01,
#  0.15,
#  -0.07,
#  -0.02,
#  -0.11,
#  0.18,
#  0.07,
#  0.17,
#  0.27,
#  0.33,
#  0.13,
#  0.3,
#  0.15,
#  0.12,
#  0.19,
#  0.33,
#  0.41,
#  0.29,
#  0.44,
#  0.43,
#  0.23,
#  0.24,
#  0.32,
#  0.46,
#  0.35,
#  0.48,
#  0.64,
#  0.42,
#  0.42,
#  0.55,
#  0.63,
#  0.62,
#  0.55,
#  0.69,
#  0.63,
#  0.66,
#  0.54,
#  0.64,
#  0.71]

# %%
model_set=emissions
model_set['gis_temp']=gis_temp_val
model_set['gcag_temp']=gcag_temp_val
model_set['co2_level']=co2
model_set['sea_level']=sea

# %%
model_set.head()
# Out:
#      Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 208  1959   2454       206          789        1382      40           36
# 209  1960   2569       227          849        1410      43           39
# 210  1961   2580       240          904        1349      45           42
# 211  1962   2686       263          980        1351      49           44
# 212  1963   2833       286         1052        1396      51           47
#
#      Per Capita  gis_temp  gcag_temp  co2_level  sea_level
# 208        0.83      0.03     0.0596       0.96      -48.0
# 209        0.85     -0.02     0.0204       0.71      -44.3
# 210        0.84      0.05     0.0775       0.78      -38.1
# 211        0.86      0.03     0.0888       0.56      -43.3
# 212        0.88      0.06     0.1068       0.57      -44.9

# %%
del model_set['Total']
model_set.head()
# Out:
#      Year  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  Per Capita  \
# 208  1959       206          789        1382      40           36        0.83
# 209  1960       227          849        1410      43           39        0.85
# 210  1961       240          904        1349      45           42        0.84
# 211  1962       263          980        1351      49           44        0.86
# 212  1963       286         1052        1396      51           47        0.88
#
#      gis_temp  gcag_temp  co2_level  sea_level
# 208      0.03     0.0596       0.96      -48.0
# 209     -0.02     0.0204       0.71      -44.3
# 210      0.05     0.0775       0.78      -38.1
# 211      0.03     0.0888       0.56      -43.3
# 212      0.06     0.1068       0.57      -44.9

# %%
# model_set.to_csv('Resources/model_data.csv')

# %%
curr_emissions=emissions.loc[emissions['Year']>1879]
print(curr_emissions.Year.max())
curr_emissions.head()
# Out:
# 2010
#      Year  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  Per Capita  \
# 208  1959       206          789        1382      40           36        0.83
# 209  1960       227          849        1410      43           39        0.85
# 210  1961       240          904        1349      45           42        0.84
# 211  1962       263          980        1351      49           44        0.86
# 212  1963       286         1052        1396      51           47        0.88
#
#      gis_temp  gcag_temp  co2_level  sea_level
# 208      0.03     0.0596       0.96      -48.0
# 209     -0.02     0.0204       0.71      -44.3
# 210      0.05     0.0775       0.78      -38.1
# 211      0.03     0.0888       0.56      -43.3
# 212      0.06     0.1068       0.57      -44.9

# %%
curr_temp=temp.loc[temp['Year']<2011]
curr_temp=curr_temp.sort_values("Year")
curr_temp.head()

# %%
curr_gcag=(curr_temp.loc[curr_temp['Source']=='GCAG']).Mean.to_list()
curr_gcag

# %%
curr_gistemp=(curr_temp.loc[curr_temp['Source']=='GISTEMP']).Mean.to_list()
curr_gistemp

# %%
e_and_t=curr_emissions
e_and_t['GCAG']=curr_gcag
e_and_t['GISTEMP']=curr_gistemp
e_and_t.head()

# %%
del e_and_t['Per Capita']

# %%
e_and_t

# %%
# e_and_t.to_csv('Resources/ENT.csv')

# %%
sea=pd.read_csv('Resources/sea_level_change.csv')

# %%
sea.head()

# %%
sea.Time.max()

# %%
pop=pd.read_csv('Resources/world_pop_region.csv')

# %%
pop.head()

# %%
pop.columns

# %%
grouped_pop=pop.groupby('Year')
total_pop=grouped_pop['Total population (Gapminder, HYDE & UN)'].sum()

# %%
years=pop.groupby('Year').count()
years=years.reset_index()
y=years.Year.to_list()
y

# %%
world_pop=pd.DataFrame({'Year': y,
                       'pop':total_pop})
world_pop.head()

# %%
world_pop=world_pop.loc[world_pop.Year>1879]
world_pop=world_pop.loc[world_pop.Year<2011]

# %%
globe_pop=world_pop['pop'].to_list()

# %%
urban=pd.read_csv('Resources/urbanization_rate.csv')
grouped_urban=urban.groupby('Year')
urb_rate=grouped_urban['Urban population (%) long-run to 2016 (OWID)'].mean()
urb_rate

# %%
years=urban.groupby('Year').count()
years=years.reset_index()
y=years.Year.to_list()

# %%
world_urb=pd.DataFrame({'Year': y,
                       'Urb_rate':urb_rate})
world_urb=world_urb.loc[world_urb.Year>1879]
world_urb=world_urb.loc[world_urb.Year<2011]
world_urb

# %%
e_and_t['population']=globe_pop
e_and_t.head()

# %%
hist_co2=pd.read_csv('Resources/co2_concentration.csv')
hist_co2.head()
# Out:
#      Year  CO2 concentrations (NOAA, 2018)
# 0 -803719                           207.29
# 1 -803182                           202.23
# 2 -802573                           204.86
# 3 -802060                           207.50
# 4 -801975                           202.92

# %%
hist_co2=hist_co2.loc[hist_co2.Year>1879]
hist_co2=hist_co2.loc[hist_co2.Year<2011]
concentration=hist_co2['CO2 concentrations (NOAA, 2018)']
concentration
# Out:
# 1757    287.77
# 1758    292.46
# 1759    289.49
# 1760    288.12
# 1761    294.34
#          ...
# 1858    381.90
# 1859    383.79
# 1860    385.60
# 1861    387.43
# 1862    389.90
# Name: CO2 concentrations (NOAA, 2018), Length: 106, dtype: float64

# %%
e_and_t=pd.read_csv('Resources/ENT.csv')
e_and_t.head()
# Out:
#    Unnamed: 0  Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  \
# 0         129  1880    236         0            3         233       0
# 1         130  1881    243         0            4         239       0
# 2         131  1882    256         0            4         252       0
# 3         132  1883    272         0            3         269       0
# 4         133  1884    275         0            4         271       0
#
#    Gas Flaring    GCAG  GISTEMP  population
# 0            0 -0.1148    -0.20  2785160851
# 1            0 -0.0628    -0.12  1374791585
# 2            0 -0.0648    -0.10  1384400649
# 3            0 -0.1424    -0.21  1394147464
# 4            0 -0.2009    -0.28  1403721131

# %%
e_and_t['concentration']=concentration
e_and_t.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b966948470fd> in <module>
# ----> 1 e_and_t['concentration']=concentration
#       2 e_and_t.columns
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
e_and_t.to_csv('Resources/ENT.csv')
