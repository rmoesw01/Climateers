# %%
import pandas as pd

# %%
tornado_df = pd.read_csv("Data/1950-2018alltornadoes.csv")
tornado_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 1           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 2           1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...
# 3           2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...
# 4           3  1950   1   3  1950-01-03  16:00:00   3  OH   39    1  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 64820  617020  2018  12  27  2018-12-27  10:15:00   3  LA   22    0  ...
# 64821  617021  2018  12  27  2018-12-27  10:29:00   3  MS   28    0  ...
# 64822  617022  2018  12  31  2018-12-31  12:35:00   3  KY   21    0  ...
# 64823  617023  2018  12  31  2018-12-31  13:43:00   3  IN   18    0  ...
# 64824  617024  2018  12  31  2018-12-31  14:38:00   3  IN   18    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# ...

# %%
tornado_df_clean = tornado_df.rename(columns = {"st": "State", "inj":"Injuries", "fat":"Fatalities","mag":"Magnitude",
                                                "loss":"Property_Loss","closs":"Crop_loss","slat":"Lat_Start",
                                                "slon":"Long_Start","elat":"Lat_End","elon":"Long_End", "len":"Length_(mi)", "wid":"Width_(yds)"})

# %%
tornado_df_clean.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'State', 'stf', 'stn',
#        'Magnitude', 'Injuries', 'Fatalities', 'Property_Loss', 'Crop_loss',
#        'Lat_Start', 'Long_Start', 'Lat_End', 'Long_End', 'Length_(mi)',
#        'Width_(yds)', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %%
tornado_df_clean_reduced = tornado_df_clean[["yr","date", "Magnitude","State","Injuries","Fatalities", "Property_Loss",
                                            "Crop_loss", "Lat_Start","Long_Start", "Lat_End","Long_End", "Length_(mi)","Width_(yds)"]]

# %%
tornado_df_clean_reduced
# Out:
#          yr        date  Magnitude State  Injuries  Fatalities  Property_Loss  \
# 0      1950  1950-01-03          3    MO         3           0            6.0
# 1      1950  1950-01-03          3    MO         3           0            6.0
# 2      1950  1950-01-03          3    IL         0           0            5.0
# 3      1950  1950-01-03          3    IL         3           0            5.0
# 4      1950  1950-01-03          1    OH         1           0            4.0
# ...     ...         ...        ...   ...       ...         ...            ...
# 64820  2018  2018-12-27          1    LA         0           0         7000.0
# 64821  2018  2018-12-27          0    MS         0           0        15000.0
# 64822  2018  2018-12-31          1    KY         0           0        55000.0
# 64823  2018  2018-12-31          1    IN         0           0        50000.0
# 64824  2018  2018-12-31          1    IN         0           0        20000.0
#
# ...

# %%
tornado_df_clean_reduced.groupby(["Magnitude"]).count()
# Out:
#               yr   date  State  Injuries  Fatalities  Property_Loss  \
# Magnitude
# -9           111    111    111       111         111            111
#  0         29884  29884  29884     29884       29884          29884
#  1         21829  21829  21829     21829       21829          21829
#  2          9496   9496   9496      9496        9496           9496
#  3          2703   2703   2703      2703        2703           2703
#  4           714    714    714       714         714            714
#  5            88     88     88        88          88             88
#
#            Crop_loss  Lat_Start  Long_Start  Lat_End  Long_End  Length_(mi)  \
# Magnitude
# -9               111        111         111      111       111          111
#  0             29884      29884       29884    29884     29884        29884
#  1             21829      21829       21829    21829     21829        21829
#  2              9496       9496        9496     9496      9496         9496
# ...

# %%
year = tornado_df_clean_reduced.groupby(["yr"]).count()

# %%
year
# Out:
#       date  Magnitude  State  Injuries  Fatalities  Property_Loss  Crop_loss  \
# yr
# 1950   206        206    206       206         206            206        206
# 1951   261        261    261       261         261            261        261
# 1952   246        246    246       246         246            246        246
# 1953   442        442    442       442         442            442        442
# 1954   570        570    570       570         570            570        570
# ...    ...        ...    ...       ...         ...            ...        ...
# 2014   906        906    906       906         906            906        906
# 2015  1212       1212   1212      1212        1212           1212       1212
# 2016   990        990    990       990         990            990        990
# 2017  1473       1473   1473      1473        1473           1473       1473
# 2018  1145       1145   1145      1145        1145           1145       1145
#
# ...

# %%
tornado_df_final = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"]==0) |
                                                 (tornado_df_clean_reduced["Magnitude"]==1) |
                                                 (tornado_df_clean_reduced["Magnitude"]==2) | 
                                                 (tornado_df_clean_reduced["Magnitude"]==3) | 
                                                 (tornado_df_clean_reduced["Magnitude"]==4) | 
                                                 (tornado_df_clean_reduced["Magnitude"]==5),:]

# %%
tornado_df_final.groupby(["yr"]).count()
# Out:
#       date  Magnitude  State  Injuries  Fatalities  Property_Loss  Crop_loss  \
# yr
# 1950   206        206    206       206         206            206        206
# 1951   261        261    261       261         261            261        261
# 1952   246        246    246       246         246            246        246
# 1953   442        442    442       442         442            442        442
# 1954   570        570    570       570         570            570        570
# ...    ...        ...    ...       ...         ...            ...        ...
# 2014   906        906    906       906         906            906        906
# 2015  1212       1212   1212      1212        1212           1212       1212
# 2016   960        960    960       960         960            960        960
# 2017  1409       1409   1409      1409        1409           1409       1409
# 2018  1128       1128   1128      1128        1128           1128       1128
#
# ...
