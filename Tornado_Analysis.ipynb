# %%
import pandas as pd

# %%
all_parameters = pd.read_csv("Data/All_parameters.csv")
all_parameters
# Out:
#      Year  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 0    1880       0.0          3.0       233.0     0.0          0.0
# 1    1881       0.0          4.0       239.0     0.0          0.0
# 2    1882       0.0          4.0       252.0     0.0          0.0
# 3    1883       0.0          3.0       269.0     0.0          0.0
# 4    1884       0.0          4.0       271.0     0.0          0.0
# ..    ...       ...          ...         ...     ...          ...
# 133  2013       NaN          NaN         NaN     NaN          NaN
# 134  2014       NaN          NaN         NaN     NaN          NaN
# 135  2015       NaN          NaN         NaN     NaN          NaN
# 136  2016       NaN          NaN         NaN     NaN          NaN
# 137  2017       NaN          NaN         NaN     NaN          NaN
#
#        population  GCAG_TEMP  GIS_TEMP  Sea_anomaly_temp   GMSL  CO2_Increase  \
# 0    2.785161e+09    -0.1148     -0.20         -0.470009 -158.7           NaN
# 1    1.374792e+09    -0.0628     -0.12         -0.356879 -153.1           NaN
# 2    1.384401e+09    -0.0648     -0.10         -0.372661 -169.9           NaN
# 3    1.394147e+09    -0.1424     -0.21         -0.448443 -164.6           NaN
# 4    1.403721e+09    -0.2009     -0.28         -0.589754 -143.7           NaN
# ..            ...        ...       ...               ...    ...           ...
# 133           NaN     0.6679      0.65          0.584674   67.7          2.41
# 134           NaN     0.7408      0.74          0.751255    NaN          2.04
# 135           NaN     0.8998      0.87          0.935577    NaN          2.94
# 136           NaN     0.9363      0.99               NaN    NaN          2.86
# 137           NaN        NaN       NaN               NaN    NaN          2.14
#
#      CSIRO Adjusted Sea Level  Glacier_mass
# 0                    0.000000           NaN
# 1                    0.220472           NaN
# 2                   -0.440945           NaN
# 3                   -0.232283           NaN
# 4                    0.590551           NaN
# ..                        ...           ...
# 133                  8.980315       -27.817
# 134                       NaN       -28.652
# 135                       NaN           NaN
# 136                       NaN           NaN
# 137                       NaN           NaN
#
# [138 rows x 14 columns]

# %%
tornado_df = pd.read_csv("Data/1950-2018alltornadoes.csv")
tornado_df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 1           1  1950   1   3  1950-01-03  11:00:00   3  MO   29    1  ...
# 2           1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...
# 3           2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...
# 4           3  1950   1   3  1950-01-03  16:00:00   3  OH   39    1  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 64820  617020  2018  12  27  2018-12-27  10:15:00   3  LA   22    0  ...
# 64821  617021  2018  12  27  2018-12-27  10:29:00   3  MS   28    0  ...
# 64822  617022  2018  12  31  2018-12-31  12:35:00   3  KY   21    0  ...
# 64823  617023  2018  12  31  2018-12-31  13:43:00   3  IN   18    0  ...
# 64824  617024  2018  12  31  2018-12-31  14:38:00   3  IN   18    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# 0      9.50  150   2   0   1    0   0   0   0   0
# 1      6.20  150   2   1   2  189   0   0   0   0
# 2      3.30  100   2   1   2  119   0   0   0   0
# 3      3.60  130   1   1   1  135   0   0   0   0
# 4      0.10   10   1   1   1  161   0   0   0   0
# ...     ...  ...  ..  ..  ..  ...  ..  ..  ..  ..
# 64820  0.60   25   1   1   1    1   0   0   0   0
# 64821  1.29  100   1   1   1  163   0   0   0   0
# 64822  0.76  125   1   1   1  221   0   0   0   0
# 64823  2.01   50   1   1   1  147   0   0   0   0
# 64824  2.20  140   1   1   1   61   0   0   0   0
#
# [64825 rows x 29 columns]

# %%
del tornado_df['om']
del tornado_df['mo']
del tornado_df['dy']
del tornado_df['date']
del tornado_df['time']

# %%
tornado_df
# Out:
#          yr  tz  st  stf  stn  mag  inj  fat     loss  closs  ...   len  wid  \
# 0      1950   3  MO   29    1    3    3    0      6.0    0.0  ...  9.50  150
# 1      1950   3  MO   29    1    3    3    0      6.0    0.0  ...  6.20  150
# 2      1950   3  IL   17    1    3    0    0      5.0    0.0  ...  3.30  100
# 3      1950   3  IL   17    2    3    3    0      5.0    0.0  ...  3.60  130
# 4      1950   3  OH   39    1    1    1    0      4.0    0.0  ...  0.10   10
# ...     ...  ..  ..  ...  ...  ...  ...  ...      ...    ...  ...   ...  ...
# 64820  2018   3  LA   22    0    1    0    0   7000.0    0.0  ...  0.60   25
# 64821  2018   3  MS   28    0    0    0    0  15000.0    0.0  ...  1.29  100
# 64822  2018   3  KY   21    0    1    0    0  55000.0    0.0  ...  0.76  125
# 64823  2018   3  IN   18    0    1    0    0  50000.0    0.0  ...  2.01   50
# 64824  2018   3  IN   18    0    1    0    0  20000.0    0.0  ...  2.20  140
#
#        ns  sn  sg   f1  f2  f3  f4  fc
# 0       2   0   1    0   0   0   0   0
# 1       2   1   2  189   0   0   0   0
# 2       2   1   2  119   0   0   0   0
# 3       1   1   1  135   0   0   0   0
# 4       1   1   1  161   0   0   0   0
# ...    ..  ..  ..  ...  ..  ..  ..  ..
# 64820   1   1   1    1   0   0   0   0
# 64821   1   1   1  163   0   0   0   0
# 64822   1   1   1  221   0   0   0   0
# 64823   1   1   1  147   0   0   0   0
# 64824   1   1   1   61   0   0   0   0
#
# [64825 rows x 24 columns]

# %%
tornado_df_clean = tornado_df.rename(columns = {"yr":"Year","st": "State", "inj":"Injuries", "fat":"Fatalities","mag":"Magnitude",
                                                "loss":"Property_Loss","closs":"Crop_loss","slat":"Lat_Start",
                                                "slon":"Long_Start","elat":"Lat_End","elon":"Long_End", "len":"Length_(mi)", "wid":"Width_(yds)"})

# %%
tornado_df_clean
# Out:
#        Year  tz State  stf  stn  Magnitude  Injuries  Fatalities  \
# 0      1950   3    MO   29    1          3         3           0
# 1      1950   3    MO   29    1          3         3           0
# 2      1950   3    IL   17    1          3         0           0
# 3      1950   3    IL   17    2          3         3           0
# 4      1950   3    OH   39    1          1         1           0
# ...     ...  ..   ...  ...  ...        ...       ...         ...
# 64820  2018   3    LA   22    0          1         0           0
# 64821  2018   3    MS   28    0          0         0           0
# 64822  2018   3    KY   21    0          1         0           0
# 64823  2018   3    IN   18    0          1         0           0
# 64824  2018   3    IN   18    0          1         0           0
#
#        Property_Loss  Crop_loss  ...  Length_(mi)  Width_(yds)  ns  sn  sg  \
# 0                6.0        0.0  ...         9.50          150   2   0   1
# 1                6.0        0.0  ...         6.20          150   2   1   2
# 2                5.0        0.0  ...         3.30          100   2   1   2
# 3                5.0        0.0  ...         3.60          130   1   1   1
# 4                4.0        0.0  ...         0.10           10   1   1   1
# ...              ...        ...  ...          ...          ...  ..  ..  ..
# 64820         7000.0        0.0  ...         0.60           25   1   1   1
# 64821        15000.0        0.0  ...         1.29          100   1   1   1
# 64822        55000.0        0.0  ...         0.76          125   1   1   1
# 64823        50000.0        0.0  ...         2.01           50   1   1   1
# 64824        20000.0        0.0  ...         2.20          140   1   1   1
#
#         f1  f2  f3  f4  fc
# 0        0   0   0   0   0
# 1      189   0   0   0   0
# 2      119   0   0   0   0
# 3      135   0   0   0   0
# 4      161   0   0   0   0
# ...    ...  ..  ..  ..  ..
# 64820    1   0   0   0   0
# 64821  163   0   0   0   0
# 64822  221   0   0   0   0
# 64823  147   0   0   0   0
# 64824   61   0   0   0   0
#
# [64825 rows x 24 columns]

# %%
tornado_df_clean_reduced = tornado_df_clean[["Year", "Magnitude","State","Injuries","Fatalities",  "Lat_Start","Long_Start", "Lat_End","Long_End", "Length_(mi)","Width_(yds)"]]

# %%
tornado_df_clean_reduced["Count"]=1
tornado_df_clean_reduced
# Out:
# C:\Users\Amber\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Year  Magnitude State  Injuries  Fatalities  Lat_Start  Long_Start  \
# 0      1950          3    MO         3           0    38.7700    -90.2200
# 1      1950          3    MO         3           0    38.7700    -90.2200
# 2      1950          3    IL         0           0    38.8200    -90.1200
# 3      1950          3    IL         3           0    39.1000    -89.3000
# 4      1950          1    OH         1           0    40.8800    -84.5800
# ...     ...        ...   ...       ...         ...        ...         ...
# 64820  2018          1    LA         0           0    30.1302    -92.3645
# 64821  2018          0    MS         0           0    32.6431    -90.4509
# 64822  2018          1    KY         0           0    36.8900    -87.9870
# 64823  2018          1    IN         0           0    38.1813    -86.8863
# 64824  2018          1    IN         0           0    38.0935    -86.0869
#
#        Lat_End  Long_End  Length_(mi)  Width_(yds)  Count
# 0      38.8300  -90.0300         9.50          150      1
# 1      38.8200  -90.1200         6.20          150      1
# 2      38.8300  -90.0300         3.30          100      1
# 3      39.1200  -89.2300         3.60          130      1
# 4       0.0000    0.0000         0.10           10      1
# ...        ...       ...          ...          ...    ...
# 64820  30.1321  -92.3547         0.60           25      1
# 64821  32.6427  -90.4288         1.29          100      1
# 64822  36.8915  -87.9734         0.76          125      1
# 64823  38.2006  -86.8585         2.01           50      1
# 64824  38.1000  -86.0470         2.20          140      1
#
# [64825 rows x 12 columns]

# %%
years = tornado_df_clean_reduced["Year"].unique()
Mag_0 = []
Mag_1 = []
Mag_2 = []
Mag_3 = []
Mag_4 = []
Mag_5 = []
tornado_total = []

for year in years:
    total = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Year"] == year),:]
    tornado_total.append(total.shape[0])
    sum_0 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 0) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_0.append(sum_0.shape[0])
    sum_1 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 1) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_1.append(sum_1.shape[0])
    sum_2 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 2) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_2.append(sum_2.shape[0])
    sum_3 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 3) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_3.append(sum_3.shape[0])
    sum_4 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 4) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_4.append(sum_4.shape[0])
    sum_5 = tornado_df_clean_reduced.loc[(tornado_df_clean_reduced["Magnitude"] == 5) & 
                                    (tornado_df_clean_reduced["Year"] == year),:]
    Mag_5.append(sum_5.shape[0])

# %%
#zip together above lists
tornado_data = list(zip(years, Mag_0, Mag_1,Mag_2,Mag_3,Mag_4,Mag_5,tornado_total))
#make a dataframe from zipped lists and rename columns
tornado_data = pd.DataFrame(tornado_data)
tornado_data = tornado_data.rename(columns = {0:"Year", 1:"Magnitude_0", 2:"Magnitude_1", 3:"Magnitude_2", 4: "Magnitude_3",5:"Magnitude_4", 6:"Magnitude_5",7:"Tornado_total"})
# atlantic_ocean_data = atlantic_ocean_data[:62]
# tornado_data = atlantic_ocean_data[29:160]
tornado_data
# Out:
#     Year  Magnitude_0  Magnitude_1  Magnitude_2  Magnitude_3  Magnitude_4  \
# 0   1950           16           86           71           26            7
# 1   1951           49          100           84           23            5
# 2   1952           32           82           72           40           20
# 3   1953           66          160          143           46           22
# 4   1954           91          226          193           49           11
# ..   ...          ...          ...          ...          ...          ...
# 64  2014          478          325           76           20            7
# 65  2015          704          415           69           19            5
# 66  2016          533          318           80           27            2
# 67  2017          637          607          146           16            3
# 68  2018          628          406           81           13            0
#
#     Magnitude_5  Tornado_total
# 0             0            206
# 1             0            261
# 2             0            246
# 3             5            442
# 4             0            570
# ..          ...            ...
# 64            0            906
# 65            0           1212
# 66            0            990
# 67            0           1473
# 68            0           1145
#
# [69 rows x 8 columns]

# %%
gw_data_tornado = pd.merge(all_parameters, tornado_data, on = "Year", how = "inner")
gw_data_tornado_condensed = gw_data_tornado[9:60]
gw_data_tornado_condensed.head(20)
# Out:
#     Year  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 9   1959     206.0        789.0      1382.0    40.0         36.0
# 10  1960     227.0        849.0      1410.0    43.0         39.0
# 11  1961     240.0        904.0      1349.0    45.0         42.0
# 12  1962     263.0        980.0      1351.0    49.0         44.0
# 13  1963     286.0       1052.0      1396.0    51.0         47.0
# 14  1964     316.0       1137.0      1435.0    57.0         51.0
# 15  1965     337.0       1219.0      1460.0    59.0         55.0
# 16  1966     364.0       1323.0      1478.0    63.0         60.0
# 17  1967     392.0       1423.0      1448.0    65.0         66.0
# 18  1968     424.0       1551.0      1448.0    70.0         73.0
# 19  1969     467.0       1673.0      1486.0    74.0         80.0
# 20  1970     493.0       1839.0      1556.0    78.0         87.0
# 21  1971     530.0       1947.0      1559.0    84.0         88.0
# 22  1972     560.0       2057.0      1576.0    89.0         94.0
# 23  1973     588.0       2241.0      1581.0    95.0        110.0
# 24  1974     597.0       2245.0      1579.0    96.0        107.0
# 25  1975     604.0       2132.0      1673.0    95.0         92.0
# 26  1976     630.0       2314.0      1710.0   103.0        108.0
# 27  1977     650.0       2398.0      1765.0   108.0        104.0
# 28  1978     680.0       2392.0      1793.0   116.0        106.0
#
#       population  GCAG_TEMP  GIS_TEMP  Sea_anomaly_temp  ...  CO2_Increase  \
# 9   8.938733e+09     0.0596      0.03         -0.273542  ...          0.96
# 10  9.104859e+09     0.0204     -0.02         -0.303577  ...          0.71
# 11  9.275526e+09     0.0775      0.05         -0.264251  ...          0.78
# 12  9.451249e+09     0.0888      0.03         -0.271703  ...          0.56
# 13  9.633002e+09     0.1068      0.06         -0.260397  ...          0.57
# 14  9.821936e+09    -0.1495     -0.20         -0.591331  ...          0.49
# 15  1.001875e+10    -0.0780     -0.10         -0.489249  ...          1.10
# 16  1.022377e+10    -0.0227     -0.05         -0.394110  ...          1.10
# 17  1.043631e+10    -0.0131     -0.02         -0.420358  ...          0.61
# 18  1.065480e+10    -0.0296     -0.07         -0.381870  ...          0.99
# 19  1.087705e+10     0.0929      0.07         -0.087637  ...          1.32
# 20  1.110132e+10     0.0372      0.02         -0.308633  ...          1.13
# 21  1.132728e+10    -0.0783     -0.09         -0.557176  ...          0.73
# 22  1.155495e+10     0.0264      0.01         -0.205168  ...          1.47
# 23  1.178335e+10     0.1641      0.15         -0.183674  ...          1.46
# 24  1.201138e+10    -0.0719     -0.07         -0.425192  ...          0.68
# 25  1.223844e+10     0.0034     -0.02         -0.467543  ...          1.23
# 26  1.246400e+10    -0.0792     -0.11         -0.409628  ...          0.97
# 27  1.268852e+10     0.1978      0.18         -0.039769  ...          1.92
# 28  1.291359e+10     0.1123      0.07         -0.165393  ...          1.29
#
#     CSIRO Adjusted Sea Level  Glacier_mass  Magnitude_0  Magnitude_1  \
# 9                   4.358268        -8.325          145          264
# 10                  4.503937        -8.688          128          262
# 11                  4.748031        -8.935          154          243
# 12                  4.543307        -9.109          191          267
# 13                  4.480315        -9.567           98          182
# 14                  4.169291        -9.699          169          268
# 15                  4.610236        -9.298          248          300
# 16                  4.397638        -9.436          169          239
# 17                  4.452756        -9.303          282          329
# 18                  4.484252        -9.219          192          253
# 19                  4.751968        -9.732          195          220
# 20                  4.677165       -10.128          164          257
# 21                  4.881890       -10.288          188          382
# 22                  5.240157       -10.441          174          347
# 23                  5.003937       -10.538          219          497
# 24                  5.472441       -10.613          224          385
# 25                  5.409449       -10.534          307          378
# 26                  5.370079       -10.633          241          362
# 27                  5.303150       -10.682          236          420
# 28                  5.555118       -10.754          338          318
#
#     Magnitude_2  Magnitude_3  Magnitude_4  Magnitude_5  Tornado_total
# 9           157           37           11            0            614
# 10          175           47            6            1            619
# 11          233           80           11            0            721
# 12          166           37            6            0            667
# 13          154           35            7            0            476
# 14          221           48           10            3            719
# 15          251           79           39            1            918
# 16          147           27            5            6            593
# 17          247           61           21            0            940
# 18          165           42           11            5            668
# 19          143           51            8            0            617
# 20          196           40           13            1            671
# 21          243           74           13            4            904
# 22          183           39            4            0            747
# 23          305           77           16            1           1115
# 24          214          100           36           15            974
# 25          194           34           11            0            924
# 26          174           54           14            3            848
# 27          143           48           13            1            861
# 28          111           28            7            0            802
#
# [20 rows x 21 columns]

# %%
gw_data_tornado_condensed.columns
# Out:
# Index(['Year', 'Gas Fuel', 'Liquid Fuel', 'Solid Fuel', 'Cement',
#        'Gas Flaring', 'population', 'GCAG_TEMP', 'GIS_TEMP',
#        'Sea_anomaly_temp', 'GMSL', 'CO2_Increase', 'CSIRO Adjusted Sea Level',
#        'Glacier_mass', 'Magnitude_0', 'Magnitude_1', 'Magnitude_2',
#        'Magnitude_3', 'Magnitude_4', 'Magnitude_5', 'Tornado_total'],
#       dtype='object')

# %%
X=gw_data_tornado_condensed[[ 'Gas Fuel',  'Cement', 'Sea_anomaly_temp',
         'GCAG_TEMP','GIS_TEMP', 'population', 
        'GMSL','CO2_Increase']]
y=gw_data_tornado_condensed.Tornado_total

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
#modeling total tornadoes
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.7425936416985753
# Testing Score: 0.7596520383918903

# %%
X_mag_5=gw_data_tornado_condensed[[  
       'Gas Fuel', 'GCAG', 
       'CO2_Increase']]
y_mag_5=gw_data_tornado_condensed.Magnitude_5

# %%
X_train_mag_5, X_test_mag_5, y_train_mag_5, y_test_mag_5 = train_test_split(X_mag_5, y_mag_5, random_state=42)

# %%
model_mag_5 = LinearRegression()

# %%
#modeling mag 5 tornadoes
model_mag_5.fit(X_train_mag_5, y_train_mag_5)
training_score_mag_5 = model_mag_5.score(X_train_mag_5, y_train_mag_5)
testing_score_mag_5 = model_mag_5.score(X_test_mag_5, y_test_mag_5)

print(f"Training Score: {training_score_mag_5}")
print(f"Testing Score: {testing_score_mag_5}")
# Out:
# Training Score: 0.27850488801521966
# Testing Score: -0.5104543571414812
